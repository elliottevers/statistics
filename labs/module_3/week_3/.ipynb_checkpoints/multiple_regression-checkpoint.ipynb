# %%
library(statsr)
library(dplyr)
library(ggplot2)
library(GGally)

# %% [markdown]
# data(evals)

# %% [markdown]
# # Q: Which of the following statements is false about the distribution of score?

# %%
ggplot(
    data=evals,
    aes(x=score)
) +
geom_histogram(
    binwidth=.5
)
# Out:
# plot without title

# %%
boxplot(
    evals$score,
    data=evals
)
# Out:
# plot without title

# %% [markdown]
# # A: The following is *false* - the left skewness of the data suggests that the students are less likely to rate the professors highly.

# %%
ggplot(
    data = evals,
    aes(
        x = bty_avg,
        y = score
    )
) +
  geom_point(
  )
# Out:
# plot without title

# %% [markdown]
# # Q: Replot the scatterplot, but this time replace the geom_point() layer with a geom_jitter() layer. (Use ?geom_jitter to learn more.) What was misleading about the initial scatterplot?

# %%
ggplot(
    data = evals,
    aes(
        x = bty_avg,
        y = score
    )
) +
  geom_jitter(
  )
# Out:
# plot without title

# %% [markdown]
# # A: The initial scatterplot had a homogeneous density.

# %%
ggplot(
    data = evals,
    aes(
        x = bty_avg,
        y = score)
) +
  geom_jitter() +
  geom_smooth(method = "lm")
# Out:
# plot without title

# %%
ggplot(data = evals, aes(x = bty_avg, y = score)) +
  geom_jitter() +
  geom_smooth(method = "lm", se = FALSE)
# Out:
# plot without title

# %% [markdown]
# # Q: Print a summary of the linear model, write out the equation, and interpret the slope.

# %%
summary(
    lm(
        score~bty_avg,
        evals
    )
)
# Out:
# Call:
# lm(formula = score ~ bty_avg, data = evals)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9246 -0.3690  0.1420  0.3977  0.9309
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.88034    0.07614   50.96  < 2e-16 ***
# bty_avg      0.06664    0.01629    4.09 5.08e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5348 on 461 degrees of freedom
# Multiple R-squared:  0.03502,	Adjusted R-squared:  0.03293
# F-statistic: 16.73 on 1 and 461 DF,  p-value: 5.083e-05

# %% [markdown]
# # A: score $\approx$ .066 * bty_avg + 3.880 - each additional beauty point increases the score by .066

# %%
ggplot(data = evals, aes(x = bty_f1lower, y = bty_avg)) +
  geom_jitter()
# Out:
# plot without title

# %%
evals %>% 
  summarise(cor(bty_avg, bty_f1lower))
# Out:
#   cor(bty_avg, bty_f1lower)
# 1 0.8439112

# %%
ggpairs(evals, columns = 13:19)
# Out:
# plot without title

# %%
m_bty_gen <- lm(score ~ bty_avg + gender, data = evals)
summary(m_bty_gen)
# Out:
# Call:
# lm(formula = score ~ bty_avg + gender, data = evals)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8305 -0.3625  0.1055  0.4213  0.9314
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.74734    0.08466  44.266  < 2e-16 ***
# bty_avg      0.07416    0.01625   4.563 6.48e-06 ***
# gendermale   0.17239    0.05022   3.433 0.000652 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5287 on 460 degrees of freedom
# Multiple R-squared:  0.05912,	Adjusted R-squared:  0.05503
# F-statistic: 14.45 on 2 and 460 DF,  p-value: 8.177e-07

# %%
newprof <- data.frame(gender = "male", bty_avg = 3)

# %%
predict(m_bty_gen, newprof)
# Out:
#        1
# 4.142194

# %%
predict(
    m_bty_gen,
    newprof,
    interval = "prediction",
    level = 0.95
)
# Out:
#   fit      lwr      upr
# 1 4.142194 3.100559 5.183829

# %%
m_full <- lm(
    score ~ rank + ethnicity + gender + language + age + cls_perc_eval 
             + cls_students + cls_level + cls_profs + cls_credits + bty_avg 
             + pic_outfit + pic_color,
    data = evals
)
summary(m_full)
# Out:
# Call:
# lm(formula = score ~ rank + ethnicity + gender + language + age +
#     cls_perc_eval + cls_students + cls_level + cls_profs + cls_credits +
#     bty_avg + pic_outfit + pic_color, data = evals)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.77397 -0.32432  0.09067  0.35183  0.95036
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            4.0952141  0.2905277  14.096  < 2e-16 ***
# ranktenure track      -0.1475932  0.0820671  -1.798  0.07278 .
# ranktenured           -0.0973378  0.0663296  -1.467  0.14295
# ethnicitynot minority  0.1234929  0.0786273   1.571  0.11698
# gendermale             0.2109481  0.0518230   4.071 5.54e-05 ***
# languagenon-english   -0.2298112  0.1113754  -2.063  0.03965 *
# age                   -0.0090072  0.0031359  -2.872  0.00427 **
# cls_perc_eval          0.0053272  0.0015393   3.461  0.00059 ***
# cls_students           0.0004546  0.0003774   1.205  0.22896
# ...

# %%
m1 <- lm(score ~ ethnicity + gender + language + age + cls_perc_eval 
             + cls_students + cls_level + cls_profs + cls_credits + bty_avg, data = evals)
summary(m1)$adj.r.squared
# Out:
# [1] 0.1417823

# %%
m2 = lm(score ~ rank + gender + language + age + cls_perc_eval + 
    cls_students + cls_level + cls_profs + cls_credits + bty_avg, data = evals)
summary(m2)$adj.r.squared
# Out:
# [1] 0.1320486
